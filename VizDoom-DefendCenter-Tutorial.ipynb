# %% [markdown]
# # 1. Getting VizDoom Up and Running

# %%
# Import vizdoom for game env
from vizdoom import * 
# Import random for action sampling
import random
# Import time for sleeping
import time 
# Import numpy for identity matrix
import numpy as np

# %%
# Setup game
game = DoomGame()
game.load_config('github/VizDoom/scenarios/defend_the_center.cfg')
game.init()

# %%
# This is the set of actions we can take in the environment
actions = np.identity(3, dtype=np.uint8)

# %%
state = game.get_state()

# %%
state.game_variables
# Out:
# array([ 26., 100.])

# %%
# Loop through episodes 
episodes = 10 
for episode in range(episodes): 
    # Create a new episode or game 
    game.new_episode()
    # Check the game isn't done 
    while not game.is_episode_finished(): 
        # Get the game state 
        state = game.get_state()
        # Get the game image 
        img = state.screen_buffer
        # Get the game variables - ammo
        info = state.game_variables
        # Take an action
        reward = game.make_action(random.choice(actions),4)
        # Print rewward 
        print('reward:', reward) 
        time.sleep(0.02)
    print('Result:', game.get_total_reward())
    time.sleep(2)

# %%
game.close()

# %% [markdown]
# # 2. Converting it to a Gym Environment

# %%
# Import environment base class from OpenAI Gym
from gym import Env
# Import gym spaces 
from gym.spaces import Discrete, Box
# Import opencv 
import cv2

# %%
# Create Vizdoom OpenAI Gym Environment
class VizDoomGym(Env): 
    # Function that is called when we start the env
    def __init__(self, render=False): 
        # Inherit from Env
        super().__init__()
        # Setup the game 
        self.game = DoomGame()
        self.game.load_config('github/VizDoom/scenarios/defend_the_center.cfg')
        
        # Render frame logic
        if render == False: 
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)
        
        # Start the game 
        self.game.init()
        
        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8) 
        self.action_space = Discrete(3)
        
    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step 
        actions = np.identity(3)
        reward = self.game.make_action(actions[action], 4) 
        
        # Get all the other stuff we need to retun 
        if self.game.get_state(): 
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            info = ammo
        else: 
            state = np.zeros(self.observation_space.shape)
            info = 0 
        
        info = {"info":info}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info 
    
    # Define how to render the game or environment 
    def render(): 
        pass
    
    # What happens when we start a new game 
    def reset(self): 
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    
    # Grayscale the game frame and resize it 
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
    
    # Call to close down the game
    def close(self): 
        self.game.close()

# %%
env = VizDoomGym(render=True)

# %%
state = env.reset()
print(state)
# Out:
# [[[ 5]
#   [10]
#   [ 7]
#   ...
#   [ 4]
#   [ 6]
#   [10]]
#
#  [[ 3]
#   [ 3]
#   [ 4]
#   ...
#   [ 5]
#   [ 3]
#   [ 7]]
#
#  [[11]
#   [ 7]
#   [10]
#   ...
#   [ 9]
#   [ 6]
#   [ 6]]
#
#  ...
#
#  [[75]
#   [63]
#   [62]
#   ...
#   [44]
#   [71]
#   [60]]
#
#  [[15]
#   [48]
#   [47]
#   ...
#   [49]
#   [69]
#   [47]]
#
#  [[22]
#   [14]
#   [26]
#   ...
#   [57]
#   [37]
#   [39]]]

# %% [markdown]
# # 3. View Game State

# %%
env.reset()
# Out:
# array([[[ 5],
#         [10],
#         [ 7],
#         ...,
#         [ 4],
#         [ 6],
#         [10]],
#
#        [[ 3],
#         [ 3],
#         [ 4],
#         ...,
#         [ 5],
#         [ 3],
#         [ 7]],
#
#        [[11],
#         [ 7],
#         [10],
#         ...,
#         [ 9],
#         [ 6],
#         [ 6]],
#
#        ...,
#
#        [[75],
#         [63],
#         [62],
#         ...,
#         [44],
#         [71],
#         [60]],
#
#        [[15],
#         [48],
#         [47],
#         ...,
#         [49],
#         [69],
#         [47]],
#
#        [[22],
#         [14],
#         [26],
#         ...,
#         [57],
#         [37],
#         [39]]], dtype=uint8)

# %%
# Import Environment checker
from stable_baselines3.common import env_checker
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Import Environment checker
# ----> 2 from stable_baselines3.common import env_checker
#
# File c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\__init__.py:3
#       1 import os
# ----> 3 from stable_baselines3.a2c import A2C
#       4 from stable_baselines3.common.utils import get_system_info
#       5 from stable_baselines3.ddpg import DDPG
#
# File c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\a2c\__init__.py:1
# ----> 1 from stable_baselines3.a2c.a2c import A2C
#       2 from stable_baselines3.a2c.policies import CnnPolicy, MlpPolicy, MultiInputPolicy
#       4 __all__ = ["CnnPolicy", "MlpPolicy", "MultiInputPolicy", "A2C"]
#
# File c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\a2c\a2c.py:4
#       1 from typing import Any, ClassVar, Dict, Optional, Type, TypeVar, Union
#       3 import torch as th
# ----> 4 from gymnasium import spaces
#       5 from torch.nn import functional as F
#       7 from stable_baselines3.common.buffers import RolloutBuffer
#
# File c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\gymnasium\__init__.py:25
#      23 from gymnasium import envs
#      24 from gymnasium import spaces, utils, vector, wrappers, error, logger
# ---> 25 from gymnasium import experimental
#      28 __all__ = [
#      29     # core classes
#      30     "Env",
#    (...)
#      52     "logger",
#      53 ]
#      54 __version__ = "0.29.1"
#
# File c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\gymnasium\experimental\__init__.py:4
#       1 """Root __init__ of the gym experimental wrappers."""
# ----> 4 from gymnasium.experimental import functional, vector, wrappers
#       7 # from gymnasium.experimental.functional import FuncEnv
#       8 # from gymnasium.experimental.vector.async_vector_env import AsyncVectorEnv
#       9 # from gymnasium.experimental.vector.sync_vector_env import SyncVectorEnv
#      10 # from gymnasium.experimental.vector.vector_env import VectorEnv, VectorWrapper
#      13 __all__ = [
#      14     # Functional
#      15     # "FuncEnv",
#    (...)
#      24     "vector",
#      25 ]
#
# File c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\gymnasium\experimental\wrappers\__init__.py:38
#      32 from gymnasium.experimental.wrappers.rendering import (
#      33     HumanRenderingV0,
#      34     RecordVideoV0,
#      35     RenderCollectionV0,
#      36 )
#      37 from gymnasium.experimental.wrappers.stateful_action import StickyActionV0
# ---> 38 from gymnasium.experimental.wrappers.stateful_observation import (
#      39     DelayObservationV0,
#      40     FrameStackObservationV0,
#      41     MaxAndSkipObservationV0,
#      42     NormalizeObservationV0,
#      43     TimeAwareObservationV0,
#      44 )
#      45 from gymnasium.experimental.wrappers.stateful_reward import NormalizeRewardV1
#      48 # Todo - Add legacy wrapper to new wrapper error for users when merged into gymnasium.wrappers
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:671, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:839, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:934, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1032, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
env_checker.check_env(env)

# %% [markdown]
# # 3. View State

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.19.0)
# Requirement already satisfied: six>=1.5 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# %%
env.close()

# %% [markdown]
# # 4. Setup Callback

# %%
# !pip install torch==1.10.1+cu113 torchvision==0.11.2+cu113 torchaudio===0.10.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# Out:
# ^C
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 98, in read
#     data: bytes = self.__fp.read(amt)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\http\client.py", line 459, in read
#     n = self.readinto(b)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\http\client.py", line 503, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\ssl.py", line 1274, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\ssl.py", line 1132, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\cli\base_command.py", line 180, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\cli\req_command.py", line 245, in wrapper
#     return func(self, options, args)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 95, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 397, in resolve
#     self._add_to_criteria(self.state.criteria, r, parent=None)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 173, in _add_to_criteria
#     if not criterion.candidates:
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 156, in __bool__
#     return bool(self._sequence)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 155, in __bool__
#     return any(self)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 47, in _iter_built
#     candidate = func()
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 182, in _make_candidate_from_link
#     base: Optional[BaseCandidate] = self._make_base_candidate_from_link(
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 228, in _make_base_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 290, in __init__
#     super().__init__(
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 222, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 301, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\operations\prepare.py", line 525, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\operations\prepare.py", line 596, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\operations\prepare.py", line 168, in unpack_url
#     file = get_http_url(
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\operations\prepare.py", line 109, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\network\download.py", line 147, in __call__
#     for chunk in chunks:
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\cli\progress_bars.py", line 53, in _rich_progress_bar
#     for chunk in iterable:
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_internal\network\utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_vendor\urllib3\response.py", line 622, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_vendor\urllib3\response.py", line 587, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='download.pytorch.org', port=443): Read timed out.
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# Collecting torch==1.10.1+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.10.1%2Bcu113-cp38-cp38-win_amd64.whl (2442.4 MB)
#      ---------------------------------------- 0.0/2.4 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.4 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.4 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.4 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.4 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.4 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.4 GB 2.6 MB/s eta 0:15:55
#      ---------------------------------------- 0.0/2.4 GB 2.6 MB/s eta 0:15:55
#      ---------------------------------------- 0.0/2.4 GB 2.6 MB/s eta 0:15:55
#      ---------------------------------------- 0.0/2.4 GB 2.6 MB/s eta 0:15:55
#      ---------------------------------------- 0.0/2.4 GB 286.7 kB/s eta 2:21:59
#      ---------------------------------------- 0.0/2.4 GB 286.7 kB/s eta 2:21:59
#      ---------------------------------------- 0.0/2.4 GB 851.9 kB/s eta 0:47:37
#      ---------------------------------------- 0.0/2.4 GB 852.1 kB/s eta 0:47:37
#      ---------------------------------------- 0.0/2.4 GB 851.2 kB/s eta 0:47:40
#      ---------------------------------------- 0.0/2.4 GB 847.0 kB/s eta 0:47:54
#      ---------------------------------------- 0.0/2.4 GB 855.4 kB/s eta 0:47:25
#      ---------------------------------------- 0.0/2.4 GB 889.2 kB/s eta 0:45:37
#      ---------------------------------------- 0.0/2.4 GB 898.3 kB/s eta 0:45:09
#      ---------------------------------------- 0.0/2.4 GB 898.2 kB/s eta 0:45:09
#      ---------------------------------------- 0.0/2.4 GB 893.8 kB/s eta 0:45:22
#      ---------------------------------------- 0.0/2.4 GB 898.2 kB/s eta 0:45:09
#      ---------------------------------------- 0.0/2.4 GB 949.0 kB/s eta 0:42:44
#      ---------------------------------------- 0.0/2.4 GB 950.1 kB/s eta 0:42:40
#      ---------------------------------------- 0.0/2.4 GB 950.1 kB/s eta 0:42:40
#      ---------------------------------------- 0.0/2.4 GB 986.0 kB/s eta 0:41:07
#      ---------------------------------------- 0.0/2.4 GB 1.3 MB/s eta 0:30:58
#      ---------------------------------------- 0.0/2.4 GB 1.3 MB/s eta 0:31:01
#      ---------------------------------------- 0.0/2.4 GB 1.3 MB/s eta 0:30:20
#      ---------------------------------------- 0.0/2.4 GB 1.3 MB/s eta 0:30:31
#      ---------------------------------------- 0.0/2.4 GB 1.7 MB/s eta 0:24:20
#      ---------------------------------------- 0.0/2.4 GB 1.7 MB/s eta 0:23:28
#      ---------------------------------------- 0.0/2.4 GB 1.8 MB/s eta 0:22:47
#      ---------------------------------------- 0.0/2.4 GB 1.8 MB/s eta 0:22:58
#      ---------------------------------------- 0.0/2.4 GB 1.8 MB/s eta 0:22:17
#      ---------------------------------------- 0.0/2.4 GB 2.1 MB/s eta 0:19:15
#      ---------------------------------------- 0.0/2.4 GB 2.1 MB/s eta 0:18:52
#      ---------------------------------------- 0.0/2.4 GB 2.1 MB/s eta 0:19:07
#      ---------------------------------------- 0.0/2.4 GB 2.2 MB/s eta 0:18:26
#      ---------------------------------------- 0.0/2.4 GB 2.5 MB/s eta 0:16:27
#      ---------------------------------------- 0.0/2.4 GB 2.5 MB/s eta 0:16:31
#      ---------------------------------------- 0.0/2.4 GB 2.5 MB/s eta 0:16:31
#      ---------------------------------------- 0.0/2.4 GB 2.5 MB/s eta 0:16:24
#      ---------------------------------------- 0.0/2.4 GB 2.7 MB/s eta 0:14:47
#      ---------------------------------------- 0.0/2.4 GB 2.8 MB/s eta 0:14:39
#      ---------------------------------------- 0.0/2.4 GB 2.8 MB/s eta 0:14:43
#      ---------------------------------------- 0.0/2.4 GB 2.8 MB/s eta 0:14:39
#      ---------------------------------------- 0.0/2.4 GB 2.8 MB/s eta 0:14:39
#      ---------------------------------------- 0.0/2.4 GB 3.1 MB/s eta 0:13:03
#      ---------------------------------------- 0.0/2.4 GB 3.1 MB/s eta 0:13:03
#      ---------------------------------------- 0.0/2.4 GB 5.5 MB/s eta 0:07:23
#      ---------------------------------------- 0.0/2.4 GB 5.3 MB/s eta 0:07:38
#      ---------------------------------------- 0.0/2.4 GB 5.4 MB/s eta 0:07:27
#      ---------------------------------------- 0.0/2.4 GB 5.7 MB/s eta 0:07:05
#      ---------------------------------------- 0.0/2.4 GB 5.7 MB/s eta 0:07:01
#      ---------------------------------------- 0.0/2.4 GB 5.8 MB/s eta 0:06:57
#      ---------------------------------------- 0.0/2.4 GB 5.9 MB/s eta 0:06:50
#      ---------------------------------------- 0.0/2.4 GB 5.8 MB/s eta 0:06:54
#      ---------------------------------------- 0.0/2.4 GB 6.2 MB/s eta 0:06:27
#      ---------------------------------------- 0.0/2.4 GB 6.4 MB/s eta 0:06:16
#      ---------------------------------------- 0.0/2.4 GB 6.4 MB/s eta 0:06:16
#      ---------------------------------------- 0.0/2.4 GB 6.2 MB/s eta 0:06:31
#      ---------------------------------------- 0.0/2.4 GB 6.7 MB/s eta 0:06:02
#      ---------------------------------------- 0.0/2.4 GB 6.7 MB/s eta 0:05:58
#       --------------------------------------- 0.0/2.4 GB 6.7 MB/s eta 0:05:58
#       --------------------------------------- 0.0/2.4 GB 6.5 MB/s eta 0:06:09
#       --------------------------------------- 0.0/2.4 GB 6.4 MB/s eta 0:06:16
#       --------------------------------------- 0.0/2.4 GB 6.7 MB/s eta 0:06:02
#       --------------------------------------- 0.0/2.4 GB 6.7 MB/s eta 0:06:01
#       --------------------------------------- 0.0/2.4 GB 7.0 MB/s eta 0:05:43
#       --------------------------------------- 0.0/2.4 GB 7.4 MB/s eta 0:05:28
#       --------------------------------------- 0.0/2.4 GB 7.2 MB/s eta 0:05:35
#       --------------------------------------- 0.0/2.4 GB 7.0 MB/s eta 0:05:46
#       --------------------------------------- 0.0/2.4 GB 7.0 MB/s eta 0:05:46
#       --------------------------------------- 0.0/2.4 GB 7.5 MB/s eta 0:05:21
#       --------------------------------------- 0.0/2.4 GB 7.4 MB/s eta 0:05:24
#       --------------------------------------- 0.0/2.4 GB 7.4 MB/s eta 0:05:24
#       --------------------------------------- 0.0/2.4 GB 7.2 MB/s eta 0:05:35
#       --------------------------------------- 0.0/2.4 GB 7.8 MB/s eta 0:05:09
#       --------------------------------------- 0.0/2.4 GB 7.7 MB/s eta 0:05:13
#       --------------------------------------- 0.0/2.4 GB 7.7 MB/s eta 0:05:13
#       --------------------------------------- 0.0/2.4 GB 7.6 MB/s eta 0:05:16
#       --------------------------------------- 0.0/2.4 GB 7.8 MB/s eta 0:05:09
#       --------------------------------------- 0.0/2.4 GB 8.2 MB/s eta 0:04:54
#       --------------------------------------- 0.0/2.4 GB 8.2 MB/s eta 0:04:54
#       --------------------------------------- 0.0/2.4 GB 8.2 MB/s eta 0:04:54
#       --------------------------------------- 0.0/2.4 GB 8.8 MB/s eta 0:04:32
#       --------------------------------------- 0.0/2.4 GB 8.6 MB/s eta 0:04:39
#       --------------------------------------- 0.0/2.4 GB 8.5 MB/s eta 0:04:43
#       --------------------------------------- 0.0/2.4 GB 8.5 MB/s eta 0:04:43
#       --------------------------------------- 0.0/2.4 GB 9.1 MB/s eta 0:04:25
#       --------------------------------------- 0.0/2.4 GB 9.4 MB/s eta 0:04:17
#       --------------------------------------- 0.0/2.4 GB 9.1 MB/s eta 0:04:24
#       --------------------------------------- 0.0/2.4 GB 8.7 MB/s eta 0:04:35
#       --------------------------------------- 0.0/2.4 GB 8.7 MB/s eta 0:04:35
#       --------------------------------------- 0.0/2.4 GB 9.4 MB/s eta 0:04:17
#       --------------------------------------- 0.0/2.4 GB 9.2 MB/s eta 0:04:21
#       --------------------------------------- 0.0/2.4 GB 9.0 MB/s eta 0:04:28
#       --------------------------------------- 0.0/2.4 GB 9.0 MB/s eta 0:04:28
#       --------------------------------------- 0.0/2.4 GB 8.6 MB/s eta 0:04:39
#       --------------------------------------- 0.0/2.4 GB 8.7 MB/s eta 0:04:35
#       --------------------------------------- 0.0/2.4 GB 9.0 MB/s eta 0:04:28
#       --------------------------------------- 0.0/2.4 GB 9.0 MB/s eta 0:04:28
#       --------------------------------------- 0.0/2.4 GB 9.2 MB/s eta 0:04:20
#       --------------------------------------- 0.0/2.4 GB 9.1 MB/s eta 0:04:24
#       --------------------------------------- 0.0/2.4 GB 9.0 MB/s eta 0:04:28
#       --------------------------------------- 0.0/2.4 GB 9.0 MB/s eta 0:04:28
#       --------------------------------------- 0.0/2.4 GB 8.8 MB/s eta 0:04:31
#       --------------------------------------- 0.0/2.4 GB 9.0 MB/s eta 0:04:27
#       --------------------------------------- 0.1/2.4 GB 9.2 MB/s eta 0:04:20
#       --------------------------------------- 0.1/2.4 GB 8.8 MB/s eta 0:04:31
#       --------------------------------------- 0.1/2.4 GB 8.8 MB/s eta 0:04:31
#       --------------------------------------- 0.1/2.4 GB 8.7 MB/s eta 0:04:34
#       --------------------------------------- 0.1/2.4 GB 8.6 MB/s eta 0:04:38
#       --------------------------------------- 0.1/2.4 GB 9.1 MB/s eta 0:04:23
#       --------------------------------------- 0.1/2.4 GB 8.8 MB/s eta 0:04:31
#       --------------------------------------- 0.1/2.4 GB 8.8 MB/s eta 0:04:30
#       --------------------------------------- 0.1/2.4 GB 8.8 MB/s eta 0:04:30
#       --------------------------------------- 0.1/2.4 GB 9.4 MB/s eta 0:04:16
#       --------------------------------------- 0.1/2.4 GB 9.2 MB/s eta 0:04:19
#       --------------------------------------- 0.1/2.4 GB 9.2 MB/s eta 0:04:19
#       --------------------------------------- 0.1/2.4 GB 9.2 MB/s eta 0:04:19
#       --------------------------------------- 0.1/2.4 GB 9.2 MB/s eta 0:04:19
#       --------------------------------------- 0.1/2.4 GB 7.9 MB/s eta 0:05:03
#       --------------------------------------- 0.1/2.4 GB 7.9 MB/s eta 0:05:03
#       --------------------------------------- 0.1/2.4 GB 7.9 MB/s eta 0:05:03
#       --------------------------------------- 0.1/2.4 GB 7.1 MB/s eta 0:05:36
#       --------------------------------------- 0.1/2.4 GB 7.2 MB/s eta 0:05:32
#       --------------------------------------- 0.1/2.4 GB 7.2 MB/s eta 0:05:32
#       --------------------------------------- 0.1/2.4 GB 7.0 MB/s eta 0:05:39
#       --------------------------------------- 0.1/2.4 GB 7.4 MB/s eta 0:05:24
#       --------------------------------------- 0.1/2.4 GB 7.3 MB/s eta 0:05:28
#       --------------------------------------- 0.1/2.4 GB 7.4 MB/s eta 0:05:25
#       --------------------------------------- 0.1/2.4 GB 7.3 MB/s eta 0:05:28
#       --------------------------------------- 0.1/2.4 GB 7.3 MB/s eta 0:05:28
#       --------------------------------------- 0.1/2.4 GB 7.5 MB/s eta 0:05:17
#       --------------------------------------- 0.1/2.4 GB 7.5 MB/s eta 0:05:17
#      - -------------------------------------- 0.1/2.4 GB 7.5 MB/s eta 0:05:17
#      - -------------------------------------- 0.1/2.4 GB 7.6 MB/s eta 0:05:13
#      - -------------------------------------- 0.1/2.4 GB 7.7 MB/s eta 0:05:09
#      - -------------------------------------- 0.1/2.4 GB 7.8 MB/s eta 0:05:06
#      - -------------------------------------- 0.1/2.4 GB 7.8 MB/s eta 0:05:06
#      - -------------------------------------- 0.1/2.4 GB 7.7 MB/s eta 0:05:09
#      - -------------------------------------- 0.1/2.4 GB 7.9 MB/s eta 0:05:02
#      - -------------------------------------- 0.1/2.4 GB 7.9 MB/s eta 0:05:02
#      - -------------------------------------- 0.1/2.4 GB 8.0 MB/s eta 0:04:58
#      - -------------------------------------- 0.1/2.4 GB 10.7 MB/s eta 0:03:42
#      - -------------------------------------- 0.1/2.4 GB 10.7 MB/s eta 0:03:42
#      - -------------------------------------- 0.1/2.4 GB 10.7 MB/s eta 0:03:42
#      - -------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:38
#      - -------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:38
#      - -------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:38
#      - -------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:34
#      - -------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:34
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:31
#      - -------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:34
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:30
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:30
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:31
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:30
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:30
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.9 MB/s eta 0:03:19
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:26
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:26
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:26
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:26
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:22
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:22
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:22
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:26
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:26
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:29
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:29
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:29
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:26
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:29
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:26
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:25
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:29
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:22
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:22
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:22
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:22
#      - -------------------------------------- 0.1/2.4 GB 11.9 MB/s eta 0:03:18
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:21
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:21
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:21
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:21
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:21
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:21
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:21
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:21
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:21
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:25
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:25
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:25
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:24
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:28
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:28
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:28
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:24
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:28
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:28
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:28
#      - -------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:31
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:28
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:24
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:31
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:24
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:24
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:24
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:30
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:19
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:19
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:19
#      - -------------------------------------- 0.1/2.4 GB 11.9 MB/s eta 0:03:16
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:19
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:19
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:22
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:26
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:22
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:26
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:26
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:26
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:26
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:29
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:26
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:26
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:22
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:22
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:25
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:26
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:29
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:29
#      -- ------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:32
#      -- ------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:32
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:29
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:25
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:29
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:25
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:25
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:25
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:22
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:21
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:21
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:25
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:28
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:28
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:28
#      -- ------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:32
#      -- ------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:32
#      -- ------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:31
#      -- ------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:32
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:28
#      -- ------------------------------------- 0.1/2.4 GB 10.7 MB/s eta 0:03:35
#      -- ------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:31
#      -- ------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:31
#      -- ------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:31
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:28
#      -- ------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:31
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:28
#      -- ------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:31
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:28
#      -- ------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:31
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:27
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:24
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:24
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:20
#      -- ------------------------------------- 0.2/2.4 GB 11.7 MB/s eta 0:03:17
#      -- ------------------------------------- 0.2/2.4 GB 11.7 MB/s eta 0:03:17
#      -- ------------------------------------- 0.2/2.4 GB 11.7 MB/s eta 0:03:16
# ...
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56
#      -------------------- ------------------- 1.2/2.4 GB 10.6 MB/s eta 0:01:56

# %%
# !pip install stable-baselines3[extra]

# %%
# Import os for file nav
import os 
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/train_defend'
LOG_DIR = './logs/log_defend'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# # 5. Train Model

# %%
# import ppo for training
from stable_baselines3 import PPO

# %%
# Non rendered environment
env = VizDoomGym()

# %%
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=4096)

# %%
model.learn(total_timesteps=100000, callback=callback)

# %% [markdown]
# # 6. Test the Model

# %%
# Import eval policy to test agent
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Reload model from disc
model = PPO.load(r'D:\Nam 2\ThayHoangAI\FPSGame\DefendCenter100k.zip')
# Out:
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: an integer is required (got type bytes)
#   warnings.warn(
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object clip_range. Consider using `custom_objects` argument to replace this object.
# Exception: an integer is required (got type bytes)
#   warnings.warn(
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\base_class.py:751: UserWarning: You are probably loading a model saved with SB3 < 1.7.0, we deactivated exact_match so you can save the model again to avoid issues in the future (see https://github.com/DLR-RM/stable-baselines3/issues/1233 for more info). Original error: Error(s) in loading state_dict for ActorCriticCnnPolicy:
# 	Missing key(s) in state_dict: "pi_features_extractor.cnn.0.weight", "pi_features_extractor.cnn.0.bias", "pi_features_extractor.cnn.2.weight", "pi_features_extractor.cnn.2.bias", "pi_features_extractor.cnn.4.weight", "pi_features_extractor.cnn.4.bias", "pi_features_extractor.linear.0.weight", "pi_features_extractor.linear.0.bias", "vf_features_extractor.cnn.0.weight", "vf_features_extractor.cnn.0.bias", "vf_features_extractor.cnn.2.weight", "vf_features_extractor.cnn.2.bias", "vf_features_extractor.cnn.4.weight", "vf_features_extractor.cnn.4.bias", "vf_features_extractor.linear.0.weight", "vf_features_extractor.linear.0.bias".
# Note: the model should still work fine, this only a warning.
#   warnings.warn(

# %%
# Create rendered environment
env = VizDoomGym(render=True)

# %%
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)
# Out:
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ViZDoomUnexpectedExitException            Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Evaluate mean reward for 10 games
# ----> 2 mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)
#
# File c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\evaluation.py:94, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      87 while (episode_counts < episode_count_targets).any():
#      88     actions, states = model.predict(
#      89         observations,  # type: ignore[arg-type]
#      90         state=states,
#      91         episode_start=episode_starts,
#      92         deterministic=deterministic,
#      93     )
# ---> 94     new_observations, rewards, dones, infos = env.step(actions)
#      95     current_rewards += rewards
#      96     current_lengths += 1
#
# File c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\shimmy\openai_gym_compatibility.py:251, in GymV21CompatibilityV0.step(self, action)
#     242 def step(self, action: ActType) -> tuple[Any, float, bool, bool, dict]:
#     243     """Steps through the environment.
#     244
#     245     Args:
#    (...)
#     249         (observation, reward, terminated, truncated, info)
#     250     """
# --> 251     obs, reward, done, info = self.gym_env.step(action)
#     253     if self.render_mode is not None:
#     254         self.render()
#
# Cell In[7], line 28, in VizDoomGym.step(self, action)
#      25 def step(self, action):
#      26     # Specify action and take step
#      27     actions = np.identity(3)
# ---> 28     reward = self.game.make_action(actions[action], 4)
#      30     # Get all the other stuff we need to retun
#      31     if self.game.get_state():
#
# ViZDoomUnexpectedExitException: Controlled ViZDoom instance exited unexpectedly.

# %%
mean_reward

# %%
model.predict(obs)

# %%
for episode in range(5): 
    obs = env.reset()
    done = False
    total_reward = 0
    while not done: 
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        # time.sleep(0.20)
        total_reward += reward
    print('Total Reward for episode {} is {}'.format(total_reward, episode))
    time.sleep(2)
