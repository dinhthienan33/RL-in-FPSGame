# %% [markdown]
# # 1. Getting VizDoom Up and Running

# %% [markdown]
# DEADLY CORRIDOR
# The purpose of this scenario is to teach the agent to navigate towards his fundamental goal (the vest) and make sure he survives at the same time.
#
# The map is a corridor with shooting monsters on both sides (6 monsters in total). A green vest is placed at the opposite end of the corridor. The reward is proportional (negative or positive) to the change in the distance between the player and the vest. If the player ignores monsters on the sides and runs straight for the vest, he will be killed somewhere along the way. To ensure this behavior difficulty level (doom_skill) = 5 (config) is needed.
#
# REWARDS:
#
# +dX for getting closer to the vest.
#
# -dX for getting further from the vest.
#
# -100 for death
#
# CONFIGURATION:
#
# 7 available buttons: move forward/backwward/left/right, turn left/right, shoot (attack)
#
# 1 available game variable: player’s health
#
# timeout = 2100
#
# difficulty level (doom_skill) = 5

# %%
# Import vizdoom for game env
from vizdoom import * 
# Import random for action sampling
import random
# Import time for sleeping
import time 
# Import numpy for identity matrix
import numpy as np

# %%
# Setup game
game = DoomGame()
game.load_config('github/VizDoom/scenarios/deadly_corridor_s2.cfg')
game.init()

# %%
# This is the set of actions we can take in the environment
actions = np.identity(7, dtype=np.uint8)

# %%
state = game.get_state()

# %%
state.game_variables
# Out:
# array([100.,   0.,   0.,  -1.])

# %%
# Loop through episodes 
episodes = 10 
for episode in range(episodes): 
    # Create a new episode or game 
    game.new_episode()
    # Check the game isn't done 
    while not game.is_episode_finished(): 
        # Get the game state 
        state = game.get_state()
        # Get the game image 
        img = state.screen_buffer
        # Get the game variables - ammo
        info = state.game_variables
        # Take an action
        reward = game.make_action(random.choice(actions),4)
        # Print rewward 
        # print('reward:', reward) 
        time.sleep(0.02)
    print('Result:', game.get_total_reward())
    time.sleep(2)
# Out:
# Result: -104.97740173339844
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 18
#      15     reward = game.make_action(random.choice(actions),4)
#      16     # Print rewward
#      17     # print('reward:', reward)
# ---> 18     time.sleep(0.02)
#      19 print('Result:', game.get_total_reward())
#      20 time.sleep(2)
#
# KeyboardInterrupt:

# %%
#S1 - 336
#S2 - -29
#S3 - -20
#S4 - -95
#S5 - -99

# %%
game.close()

# %%
state.game_variables
# Out:
# array([100.,   0.,   0.,  -1.])

# %% [markdown]
# # 2. Converting it to a Gym Environment

# %%
# Import environment base class from OpenAI Gym
from gym import Env
# Import gym spaces 
from gym.spaces import Discrete, Box
# Import opencv 
import cv2

# %%
# Create Vizdoom OpenAI Gym Environment
class VizDoomGym(Env): 
    # Function that is called when we start the env
    def __init__(self, render=False, config='github/VizDoom/scenarios/deadly_corridor_s1.cfg'): 
        # Inherit from Env
        super().__init__()
        # Setup the game 
        self.game = DoomGame()
        self.game.load_config(config)
        
        # Render frame logic
        if render == False: 
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)
        
        # Start the game 
        self.game.init()
        
        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8) 
        self.action_space = Discrete(7)
        
        # Game variables: HEALTH DAMAGE_TAKEN HITCOUNT SELECTED_WEAPON_AMMO
        self.damage_taken = 0
        self.hitcount = 0
        self.ammo = 60 ## CHANGED
        
        
    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step 
        actions = np.identity(7)
        movement_reward = self.game.make_action(actions[action], 4) 
        
        reward = 0 
        # Get all the other stuff we need to retun 
        if self.game.get_state(): 
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            
            # Reward shaping
            game_variables = self.game.get_state().game_variables
            health, damage_taken, hitcount, ammo = game_variables
            
            # Calculate reward deltas
            damage_taken_delta = -damage_taken + self.damage_taken
            self.damage_taken = damage_taken
            hitcount_delta = hitcount - self.hitcount
            self.hitcount = hitcount
            ammo_delta = ammo - self.ammo
            self.ammo = ammo
            
            reward = movement_reward + damage_taken_delta*10 + hitcount_delta*200  + ammo_delta*5 
            info = ammo
        else: 
            state = np.zeros(self.observation_space.shape)
            info = 0 
        
        info = {"info":info}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info 
    
    # Define how to render the game or environment 
    def render(): 
        pass
    
    # What happens when we start a new game 
    def reset(self): 
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    
    # Grayscale the game frame and resize it 
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
    
    # Call to close down the game
    def close(self): 
        self.game.close()

# %%
env=VizDoomGym()

# %%
env.close()

# %%
env = VizDoomGym(render=True)

# %%
res = env.step(5)

# %%
res[1]
# Out:
# -40.0

# %%
state = env.reset()

# %% [markdown]
# # 3. View Game State

# %%
env.reset()
# Out:
# array([[[32],
#         [33],
#         [25],
#         ...,
#         [27],
#         [23],
#         [24]],
#
#        [[27],
#         [33],
#         [23],
#         ...,
#         [24],
#         [24],
#         [24]],
#
#        [[20],
#         [35],
#         [23],
#         ...,
#         [24],
#         [24],
#         [24]],
#
#        ...,
#
#        [[75],
#         [63],
#         [62],
#         ...,
#         [44],
#         [71],
#         [60]],
#
#        [[15],
#         [48],
#         [47],
#         ...,
#         [49],
#         [69],
#         [47]],
#
#        [[22],
#         [14],
#         [26],
#         ...,
#         [57],
#         [37],
#         [39]]], dtype=uint8)

# %%
# Import Environment checker
from stable_baselines3.common import env_checker

# %%
env_checker.check_env(env)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 env_checker.check_env(env)
#
# File c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\env_checker.py:421, in check_env(env, warn, skip_render_check)
#     406 def check_env(env: gym.Env, warn: bool = True, skip_render_check: bool = True) -> None:
#     407     """
#     408     Check that an environment follows Gym API.
#     409     This is particularly useful when using a custom environment.
#    (...)
#     419         True by default (useful for the CI)
#     420     """
# --> 421     assert isinstance(
#     422         env, gym.Env
#     423     ), "Your environment must inherit from the gymnasium.Env class cf. https://gymnasium.farama.org/api/env/"
#     425     # ============= Check the spaces (observation and action) ================
#     426     _check_spaces(env)
#
# AssertionError: Your environment must inherit from the gymnasium.Env class cf. https://gymnasium.farama.org/api/env/

# %% [markdown]
# # 3. View State

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1
------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:38
#      - -------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:38
#      - -------------------------------------- 0.1/2.4 GB 10.7 MB/s eta 0:03:41
#      - -------------------------------------- 0.1/2.4 GB 10.7 MB/s eta 0:03:41
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:30
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:31
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:31
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:30
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:27
#      - -------------------------------------- 0.1/2.4 GB 11.9 MB/s eta 0:03:19
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:26
#      - -------------------------------------- 0.1/2.4 GB 11.9 MB/s eta 0:03:19
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:26
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:23
#      - -------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:26
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:22
#      - -------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:22
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:29
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:29
#      - -------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:29
#      - -------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:33
#      - -------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:36
#      - -------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:36
#      - -------------------------------------- 0.1/2.4 GB 10.6 MB/s eta 0:03:44
#      - -------------------------------------- 0.1/2.4 GB 10.7 MB/s eta 0:03:40
#      - -------------------------------------- 0.1/2.4 GB 10.6 MB/s eta 0:03:44
#      - -------------------------------------- 0.1/2.4 GB 10.7 MB/s eta 0:03:40
#      - -------------------------------------- 0.1/2.4 GB 10.6 MB/s eta 0:03:44
#      - -------------------------------------- 0.1/2.4 GB 10.7 MB/s eta 0:03:40
#      - -------------------------------------- 0.1/2.4 GB 10.4 MB/s eta 0:03:47
#      - -------------------------------------- 0.1/2.4 GB 10.4 MB/s eta 0:03:47
#      - -------------------------------------- 0.1/2.4 GB 10.2 MB/s eta 0:03:50
#      - -------------------------------------- 0.1/2.4 GB 10.2 MB/s eta 0:03:50
#      - -------------------------------------- 0.1/2.4 GB 10.1 MB/s eta 0:03:54
#      - -------------------------------------- 0.1/2.4 GB 10.4 MB/s eta 0:03:47
#      - -------------------------------------- 0.1/2.4 GB 9.9 MB/s eta 0:03:57
#      - -------------------------------------- 0.1/2.4 GB 9.8 MB/s eta 0:04:01
#      - -------------------------------------- 0.1/2.4 GB 9.8 MB/s eta 0:04:01
#      - -------------------------------------- 0.1/2.4 GB 9.6 MB/s eta 0:04:04
#      - -------------------------------------- 0.1/2.4 GB 9.9 MB/s eta 0:03:57
#      - -------------------------------------- 0.1/2.4 GB 9.8 MB/s eta 0:04:01
#      - -------------------------------------- 0.1/2.4 GB 10.1 MB/s eta 0:03:53
#      - -------------------------------------- 0.1/2.4 GB 10.1 MB/s eta 0:03:53
#      - -------------------------------------- 0.1/2.4 GB 10.1 MB/s eta 0:03:53
#      - -------------------------------------- 0.1/2.4 GB 10.1 MB/s eta 0:03:53
#      - -------------------------------------- 0.1/2.4 GB 9.9 MB/s eta 0:03:57
#      - -------------------------------------- 0.1/2.4 GB 10.1 MB/s eta 0:03:53
#      - -------------------------------------- 0.1/2.4 GB 10.2 MB/s eta 0:03:50
#      - -------------------------------------- 0.1/2.4 GB 10.2 MB/s eta 0:03:49
#      - -------------------------------------- 0.1/2.4 GB 10.2 MB/s eta 0:03:49
#      - -------------------------------------- 0.1/2.4 GB 10.2 MB/s eta 0:03:49
#      - -------------------------------------- 0.1/2.4 GB 10.4 MB/s eta 0:03:46
#      - -------------------------------------- 0.1/2.4 GB 9.9 MB/s eta 0:03:56
#      - -------------------------------------- 0.1/2.4 GB 10.1 MB/s eta 0:03:53
#      - -------------------------------------- 0.1/2.4 GB 10.1 MB/s eta 0:03:53
#      - -------------------------------------- 0.1/2.4 GB 10.2 MB/s eta 0:03:49
#      - -------------------------------------- 0.1/2.4 GB 10.1 MB/s eta 0:03:53
#      - -------------------------------------- 0.1/2.4 GB 9.5 MB/s eta 0:04:07
#      - -------------------------------------- 0.1/2.4 GB 9.2 MB/s eta 0:04:14
#      - -------------------------------------- 0.1/2.4 GB 9.2 MB/s eta 0:04:14
#      - -------------------------------------- 0.1/2.4 GB 9.2 MB/s eta 0:04:14
#      - -------------------------------------- 0.1/2.4 GB 9.2 MB/s eta 0:04:14
#      - -------------------------------------- 0.1/2.4 GB 9.2 MB/s eta 0:04:14
#      - -------------------------------------- 0.1/2.4 GB 9.1 MB/s eta 0:04:17
#      - -------------------------------------- 0.1/2.4 GB 9.1 MB/s eta 0:04:17
#      - -------------------------------------- 0.1/2.4 GB 9.0 MB/s eta 0:04:21
#      - -------------------------------------- 0.1/2.4 GB 9.1 MB/s eta 0:04:17
#      - -------------------------------------- 0.1/2.4 GB 9.0 MB/s eta 0:04:21
#      - -------------------------------------- 0.1/2.4 GB 9.0 MB/s eta 0:04:21
#      - -------------------------------------- 0.1/2.4 GB 9.0 MB/s eta 0:04:21
#      - -------------------------------------- 0.1/2.4 GB 9.0 MB/s eta 0:04:21
#      - -------------------------------------- 0.1/2.4 GB 8.8 MB/s eta 0:04:24
#      - -------------------------------------- 0.1/2.4 GB 9.0 MB/s eta 0:04:20
#      - -------------------------------------- 0.1/2.4 GB 9.5 MB/s eta 0:04:06
#      - -------------------------------------- 0.1/2.4 GB 9.6 MB/s eta 0:04:02
#      - -------------------------------------- 0.1/2.4 GB 9.4 MB/s eta 0:04:10
#      - -------------------------------------- 0.1/2.4 GB 9.5 MB/s eta 0:04:06
#      - -------------------------------------- 0.1/2.4 GB 10.2 MB/s eta 0:03:48
#      - -------------------------------------- 0.1/2.4 GB 10.4 MB/s eta 0:03:44
#      - -------------------------------------- 0.1/2.4 GB 10.6 MB/s eta 0:03:41
#      - -------------------------------------- 0.1/2.4 GB 10.6 MB/s eta 0:03:41
#      - -------------------------------------- 0.1/2.4 GB 10.2 MB/s eta 0:03:48
#      - -------------------------------------- 0.1/2.4 GB 10.4 MB/s eta 0:03:44
#      - -------------------------------------- 0.1/2.4 GB 10.7 MB/s eta 0:03:37
#      - -------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:34
#      - -------------------------------------- 0.1/2.4 GB 10.7 MB/s eta 0:03:37
#      - -------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:33
#      - -------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:30
#      - -------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:33
#      - -------------------------------------- 0.1/2.4 GB 10.7 MB/s eta 0:03:37
#      - -------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:33
#      - -------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:33
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:30
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:30
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:26
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:26
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:22
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:22
#      -- ------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:19
#      -- ------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:19
#      -- ------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:19
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:26
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:29
#      -- ------------------------------------- 0.1/2.4 GB 10.9 MB/s eta 0:03:32
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:29
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:29
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:25
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:25
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:25
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:22
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:21
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:21
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:21
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:25
#      -- ------------------------------------- 0.1/2.4 GB 11.3 MB/s eta 0:03:25
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:21
#      -- ------------------------------------- 0.1/2.4 GB 11.1 MB/s eta 0:03:28
#      -- ------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:18
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:21
#      -- ------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:18
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:21
#      -- ------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:17
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:21
#      -- ------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:17
#      -- ------------------------------------- 0.1/2.4 GB 11.9 MB/s eta 0:03:14
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:21
#      -- ------------------------------------- 0.1/2.4 GB 11.7 MB/s eta 0:03:17
#      -- ------------------------------------- 0.1/2.4 GB 11.5 MB/s eta 0:03:21
#      -- ------------------------------------- 0.1/2.4 GB 10.7 MB/s eta 0:03:35
#      -- ------------------------------------- 0.1/2.4 GB 10.2 MB/s eta 0:03:45
#      -- ------------------------------------- 0.1/2.4 GB 9.8 MB/s eta 0:03:56
#      -- ------------------------------------- 0.1/2.4 GB 9.5 MB/s eta 0:04:03
#      -- ------------------------------------- 0.1/2.4 GB 9.0 MB/s eta 0:04:17
#      -- ------------------------------------- 0.1/2.4 GB 8.8 MB/s eta 0:04:20
#      -- ------------------------------------- 0.1/2.4 GB 8.7 MB/s eta 0:04:24
#      -- ------------------------------------- 0.1/2.4 GB 8.6 MB/s eta 0:04:27
#      -- ------------------------------------- 0.1/2.4 GB 8.6 MB/s eta 0:04:27
#      -- ------------------------------------- 0.1/2.4 GB 8.5 MB/s eta 0:04:30
#      -- ------------------------------------- 0.1/2.4 GB 8.5 MB/s eta 0:04:30
#      -- ------------------------------------- 0.1/2.4 GB 8.4 MB/s eta 0:04:34
#      -- ------------------------------------- 0.1/2.4 GB 8.4 MB/s eta 0:04:34
#      -- ------------------------------------- 0.1/2.4 GB 8.4 MB/s eta 0:04:34
#      -- ------------------------------------- 0.1/2.4 GB 8.5 MB/s eta 0:04:30
#      -- ------------------------------------- 0.1/2.4 GB 8.6 MB/s eta 0:04:27
#      -- ------------------------------------- 0.2/2.4 GB 8.4 MB/s eta 0:04:34
#      -- ------------------------------------- 0.2/2.4 GB 8.4 MB/s eta 0:04:33
#      -- ------------------------------------- 0.2/2.4 GB 8.3 MB/s eta 0:04:37
#      -- ------------------------------------- 0.2/2.4 GB 8.2 MB/s eta 0:04:40
#      -- ------------------------------------- 0.2/2.4 GB 8.2 MB/s eta 0:04:40
#      -- ------------------------------------- 0.2/2.4 GB 8.2 MB/s eta 0:04:40
#      -- ------------------------------------- 0.2/2.4 GB 8.1 MB/s eta 0:04:44
#      -- ------------------------------------- 0.2/2.4 GB 8.0 MB/s eta 0:04:47
#      -- ------------------------------------- 0.2/2.4 GB 8.5 MB/s eta 0:04:30
#      -- ------------------------------------- 0.2/2.4 GB 10.1 MB/s eta 0:03:48
#      -- ------------------------------------- 0.2/2.4 GB 10.4 MB/s eta 0:03:40
#      -- ------------------------------------- 0.2/2.4 GB 10.4 MB/s eta 0:03:40
#      -- ------------------------------------- 0.2/2.4 GB 10.4 MB/s eta 0:03:40
#      -- ------------------------------------- 0.2/2.4 GB 10.2 MB/s eta 0:03:44
#      -- ------------------------------------- 0.2/2.4 GB 10.4 MB/s eta 0:03:40
#      -- ------------------------------------- 0.2/2.4 GB 10.4 MB/s eta 0:03:40
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:37
#      -- ------------------------------------- 0.2/2.4 GB 10.4 MB/s eta 0:03:40
#      -- ------------------------------------- 0.2/2.4 GB 10.7 MB/s eta 0:03:33
#      -- ------------------------------------- 0.2/2.4 GB 10.7 MB/s eta 0:03:33
#      -- ------------------------------------- 0.2/2.4 GB 10.7 MB/s eta 0:03:33
#      -- ------------------------------------- 0.2/2.4 GB 10.7 MB/s eta 0:03:33
#      -- ------------------------------------- 0.2/2.4 GB 10.7 MB/s eta 0:03:33
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:36
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:36
#      -- ------------------------------------- 0.2/2.4 GB 10.7 MB/s eta 0:03:33
#      -- ------------------------------------- 0.2/2.4 GB 10.7 MB/s eta 0:03:33
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:36
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:36
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:36
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:36
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:36
#      -- ------------------------------------- 0.2/2.4 GB 10.7 MB/s eta 0:03:32
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:36
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:36
#      -- ------------------------------------- 0.2/2.4 GB 10.4 MB/s eta 0:03:39
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:36
#      -- ------------------------------------- 0.2/2.4 GB 10.4 MB/s eta 0:03:39
#      -- ------------------------------------- 0.2/2.4 GB 10.4 MB/s eta 0:03:39
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:36
#      -- ------------------------------------- 0.2/2.4 GB 10.2 MB/s eta 0:03:43
#      -- ------------------------------------- 0.2/2.4 GB 10.1 MB/s eta 0:03:46
#      -- ------------------------------------- 0.2/2.4 GB 10.2 MB/s eta 0:03:42
#      -- ------------------------------------- 0.2/2.4 GB 10.2 MB/s eta 0:03:42
#      -- ------------------------------------- 0.2/2.4 GB 10.2 MB/s eta 0:03:42
#      -- ------------------------------------- 0.2/2.4 GB 10.4 MB/s eta 0:03:39
#      -- ------------------------------------- 0.2/2.4 GB 10.4 MB/s eta 0:03:39
#      -- ------------------------------------- 0.2/2.4 GB 10.1 MB/s eta 0:03:46
#      -- ------------------------------------- 0.2/2.4 GB 10.1 MB/s eta 0:03:46
#      -- ------------------------------------- 0.2/2.4 GB 10.2 MB/s eta 0:03:42
#      -- ------------------------------------- 0.2/2.4 GB 10.1 MB/s eta 0:03:45
#      -- ------------------------------------- 0.2/2.4 GB 10.2 MB/s eta 0:03:42
#      -- ------------------------------------- 0.2/2.4 GB 10.4 MB/s eta 0:03:38
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:35
#      -- ------------------------------------- 0.2/2.4 GB 10.6 MB/s eta 0:03:35
#      -------------------------- ------------- 1.6/2.4 GB 10.7 MB/s eta 0:01:15
#      -------------------------- ------------- 1.6/2.4 GB 10.9 MB/s eta 0:01:14
#      -------------------------- ------------- 1.6/2.4 GB 10.9 MB/s eta 0:01:13
#      -------------------------- ------------- 1.6/2.4 GB 10.9 MB/s eta 0:01:13
#      -------------------------- ------------- 1.6/2.4 GB 10.7 MB/s eta 0:01:15
#      -------------------------- ------------- 1.6/2.4 GB 10.6 MB/s eta 0:01:16
#      --------------------------- ------------ 1.6/2.4 GB 10.4 MB/s eta 0:01:17
#      --------------------------- ------------ 1.6/2.4 GB 10.6 MB/s eta 0:01:16
#      --------------------------- ------------ 1.6/2.4 GB 10.2 MB/s eta 0:01:18
#      --------------------------- ------------ 1.7/2.4 GB 10.2 MB/s eta 0:01:18
#      --------------------------- ------------ 1.7/2.4 GB 10.1 MB/s eta 0:01:19
#      --------------------------- ------------ 1.7/2.4 GB 10.2 MB/s eta 0:01:18
#      --------------------------- ------------ 1.7/2.4 GB 10.1 MB/s eta 0:01:19
#      --------------------------- ------------ 1.7/2.4 GB 10.6 MB/s eta 0:01:15
#      --------------------------- ------------ 1.7/2.4 GB 10.2 MB/s eta 0:01:18
#      --------------------------- ------------ 1.7/2.4 GB 10.4 MB/s eta 0:01:16
#      --------------------------- ------------ 1.7/2.4 GB 10.2 MB/s eta 0:01:18
#      --------------------------- ------------ 1.7/2.4 GB 10.1 MB/s eta 0:01:19
#      --------------------------- ------------ 1.7/2.4 GB 10.2 MB/s eta 0:01:17
#      --------------------------- ------------ 1.7/2.4 GB 10.1 MB/s eta 0:01:19
#      --------------------------- ------------ 1.7/2.4 GB 10.1 MB/s eta 0:01:18
#      --------------------------- ------------ 1.7/2.4 GB 9.9 MB/s eta 0:01:20
#      --------------------------- ------------ 1.7/2.4 GB 9.9 MB/s eta 0:01:20
#      --------------------------- ------------ 1.7/2.4 GB 9.9 MB/s eta 0:01:20
#      --------------------------- ------------ 1.7/2.4 GB 9.5 MB/s eta 0:01:23
#      --------------------------- ------------ 1.7/2.4 GB 9.5 MB/s eta 0:01:23
#      --------------------------- ------------ 1.7/2.4 GB 9.5 MB/s eta 0:01:23
#      --------------------------- ------------ 1.7/2.4 GB 9.6 MB/s eta 0:01:22
#      --------------------------- ------------ 1.7/2.4 GB 9.8 MB/s eta 0:01:20
#      --------------------------- ------------ 1.7/2.4 GB 9.8 MB/s eta 0:01:20
#      --------------------------- ------------ 1.7/2.4 GB 9.8 MB/s eta 0:01:20
#      --------------------------- ------------ 1.7/2.4 GB 9.8 MB/s eta 0:01:20
#      --------------------------- ------------ 1.7/2.4 GB 9.9 MB/s eta 0:01:19
#      --------------------------- ------------ 1.7/2.4 GB 9.9 MB/s eta 0:01:19
#      --------------------------- ------------ 1.7/2.4 GB 10.2 MB/s eta 0:01:17
#      --------------------------- ------------ 1.7/2.4 GB 10.6 MB/s eta 0:01:14
#      --------------------------- ------------ 1.7/2.4 GB 10.7 MB/s eta 0:01:13
#      --------------------------- ------------ 1.7/2.4 GB 10.7 MB/s eta 0:01:13
#      --------------------------- ------------ 1.7/2.4 GB 10.7 MB/s eta 0:01:13
#      --------------------------- ------------ 1.7/2.4 GB 11.1 MB/s eta 0:01:10
#      --------------------------- ------------ 1.7/2.4 GB 10.7 MB/s eta 0:01:13
#      --------------------------- ------------ 1.7/2.4 GB 10.4 MB/s eta 0:01:15
#      --------------------------- ------------ 1.7/2.4 GB 9.9 MB/s eta 0:01:18
#      --------------------------- ------------ 1.7/2.4 GB 9.5 MB/s eta 0:01:22
#      --------------------------- ------------ 1.7/2.4 GB 9.6 MB/s eta 0:01:21
#      --------------------------- ------------ 1.7/2.4 GB 9.5 MB/s eta 0:01:22
#      --------------------------- ------------ 1.7/2.4 GB 9.5 MB/s eta 0:01:22
#      --------------------------- ------------ 1.7/2.4 GB 9.6 MB/s eta 0:01:21
#      --------------------------- ------------ 1.7/2.4 GB 9.2 MB/s eta 0:01:24
#      --------------------------- ------------ 1.7/2.4 GB 9.5 MB/s eta 0:01:22
#      --------------------------- ------------ 1.7/2.4 GB 9.2 MB/s eta 0:01:24
#      --------------------------- ------------ 1.7/2.4 GB 9.2 MB/s eta 0:01:24
#      --------------------------- ------------ 1.7/2.4 GB 9.4 MB/s eta 0:01:23
#      --------------------------- ------------ 1.7/2.4 GB 9.5 MB/s eta 0:01:21
#      --------------------------- ------------ 1.7/2.4 GB 9.5 MB/s eta 0:01:21
#      --------------------------- ------------ 1.7/2.4 GB 9.4 MB/s eta 0:01:22
#      --------------------------- ------------ 1.7/2.4 GB 9.4 MB/s eta 0:01:22
#      --------------------------- ------------ 1.7/2.4 GB 9.4 MB/s eta 0:01:22
#      --------------------------- ------------ 1.7/2.4 GB 9.5 MB/s eta 0:01:21
#      --------------------------- ------------ 1.7/2.4 GB 9.4 MB/s eta 0:01:22
#      --------------------------- ------------ 1.7/2.4 GB 9.2 MB/s eta 0:01:23
#      --------------------------- ------------ 1.7/2.4 GB 11.5 MB/s eta 0:01:07
#      --------------------------- ------------ 1.7/2.4 GB 11.3 MB/s eta 0:01:08
#      --------------------------- ------------ 1.7/2.4 GB 11.5 MB/s eta 0:01:07
#      --------------------------- ------------ 1.7/2.4 GB 11.5 MB/s eta 0:01:07
#      --------------------------- ------------ 1.7/2.4 GB 11.5 MB/s eta 0:01:07
#      --------------------------- ------------ 1.7/2.4 GB 11.9 MB/s eta 0:01:04

# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (2.3.2)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from stable-baselines3[extra]) (1.24.3)
# Requirement already satisfied: torch>=1.13 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from stable-baselines3[extra]) (2.3.0)
# Requirement already satisfied: cloudpickle in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pandas in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from stable-baselines3[extra]) (3.7.5)
# Requirement already satisfied: opencv-python in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from stable-baselines3[extra]) (4.9.0.80)
# Requirement already satisfied: pygame in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from stable-baselines3[extra]) (2.5.2)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from stable-baselines3[extra]) (2.13.0)
# Requirement already satisfied: psutil in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from stable-baselines3[extra]) (5.9.8)
# Requirement already satisfied: tqdm in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from stable-baselines3[extra]) (4.66.4)
# Requirement already satisfied: rich in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from stable-baselines3[extra]) (13.7.1)
# Requirement already satisfied: shimmy~=1.3.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pillow in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from stable-baselines3[extra]) (10.3.0)
# Requirement already satisfied: autorom~=0.6.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: click in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.32.3)
# Requirement already satisfied: importlib-resources in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (6.4.0)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.12.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (7.1.0)
# Requirement already satisfied: ale-py~=0.8.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.64.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.6)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (69.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.43.0)
# Requirement already satisfied: filelock in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.14.0)
# Requirement already satisfied: sympy in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (1.12.1)
# Requirement already satisfied: networkx in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: jinja2 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (2024.5.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (2021.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from pandas->stable-baselines3[extra]) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from pandas->stable-baselines3[extra]) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from rich->stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: colorama in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (3.19.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.13->stable-baselines3[extra]) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.13->stable-baselines3[extra]) (2021.12.0)
# Requirement already satisfied: six>=1.5 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\apts\anaconda3\envs\rlenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)

# %%
# Import os for file nav
import os 
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/train_corridor'
LOG_DIR = './logs/log_corridor'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# # 5. Train Our Model Using Curriculum

# %%
# import ppo for training
from stable_baselines3 import PPO

# %%
# Non rendered environment
env = VizDoomGym(config='github/VizDoom/scenarios/deadly_corridor_s1.cfg')

# %% [markdown]
# # Changes made
# - Effects of hyperparameter tuning
# - Increased initial timestep length
#
# ## Possibly look into
# - Changing reward function and game variables due to bug

# %%
#model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=4096)
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.00001, n_steps=8192, clip_range=.1, gamma=.95, gae_lambda=.9)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
#model.learn(total_timesteps=40000, callback=callback)
model.learn(total_timesteps=400000, callback=callback)
# Out:
# Logging to ./logs/log_corridor\PPO_30
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.5     |
# |    ep_rew_mean     | 954      |
# | time/              |          |
# |    fps             | 60       |
# |    iterations      | 1        |
# |    time_elapsed    | 67       |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.8        |
# |    ep_rew_mean          | 971         |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 2           |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.054793693 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.85e+03    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0196      |
# |    value_loss           | 1.03e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.9        |
# |    ep_rew_mean          | 985         |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 3           |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.048270673 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.33e+03    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.021       |
# |    value_loss           | 1.29e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | 986         |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 4           |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.053120703 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.68e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.0184      |
# |    value_loss           | 9.26e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 104        |
# |    ep_rew_mean          | 995        |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 5          |
# |    time_elapsed         | 330        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.08109684 |
# |    clip_fraction        | 0.333      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.696     |
# |    explained_variance   | 0.907      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 3.66e+03   |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.0165     |
# |    value_loss           | 8.36e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.3        |
# |    ep_rew_mean          | 1.03e+03    |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 6           |
# |    time_elapsed         | 410         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.039578736 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2e+03       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0131      |
# |    value_loss           | 9.26e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 91.7       |
# |    ep_rew_mean          | 1.06e+03   |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 7          |
# |    time_elapsed         | 497        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.05520999 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.477     |
# |    explained_variance   | 0.928      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 2.35e+03   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.0149     |
# |    value_loss           | 8.73e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.2        |
# |    ep_rew_mean          | 1.05e+03    |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 8           |
# |    time_elapsed         | 583         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.049650252 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.42       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.52e+03    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.0144      |
# |    value_loss           | 8.23e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 103        |
# |    ep_rew_mean          | 1.04e+03   |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 9          |
# |    time_elapsed         | 671        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.10136389 |
# |    clip_fraction        | 0.315      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.434     |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 3.23e+03   |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.0311     |
# |    value_loss           | 6.06e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 132        |
# |    ep_rew_mean          | 951        |
# | time/                   |            |
# |    fps                  | 53         |
# |    iterations           | 10         |
# |    time_elapsed         | 763        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.19587046 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.472     |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 2.15e+03   |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0287     |
# |    value_loss           | 5.46e+03   |
# ----------------------------------------

# %%
model.load(r'D:\Nam 2\ThayHoangAI\FPSGame\DeadlyCorridor560k.zip')
# Out:
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: an integer is required (got type bytes)
#   warnings.warn(
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object clip_range. Consider using `custom_objects` argument to replace this object.
# Exception: an integer is required (got type bytes)
#   warnings.warn(
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\base_class.py:751: UserWarning: You are probably loading a model saved with SB3 < 1.7.0, we deactivated exact_match so you can save the model again to avoid issues in the future (see https://github.com/DLR-RM/stable-baselines3/issues/1233 for more info). Original error: Error(s) in loading state_dict for ActorCriticCnnPolicy:
# 	Missing key(s) in state_dict: "pi_features_extractor.cnn.0.weight", "pi_features_extractor.cnn.0.bias", "pi_features_extractor.cnn.2.weight", "pi_features_extractor.cnn.2.bias", "pi_features_extractor.cnn.4.weight", "pi_features_extractor.cnn.4.bias", "pi_features_extractor.linear.0.weight", "pi_features_extractor.linear.0.bias", "vf_features_extractor.cnn.0.weight", "vf_features_extractor.cnn.0.bias", "vf_features_extractor.cnn.2.weight", "vf_features_extractor.cnn.2.bias", "vf_features_extractor.cnn.4.weight", "vf_features_extractor.cnn.4.bias", "vf_features_extractor.linear.0.weight", "vf_features_extractor.linear.0.bias".
# Note: the model should still work fine, this only a warning.
#   warnings.warn(

# %%
env = VizDoomGym(config='github/VizDoom/scenarios/deadly_corridor_s1.cfg')
model.set_env(env)
model.learn(total_timesteps=40000, callback=callback)
# Out:
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
env = VizDoomGym(config='github/VizDoom/scenarios/deadly_corridor_s2.cfg')
model.set_env(env)
model.learn(total_timesteps=40000, callback=callback)

# %%
env = VizDoomGym(config='github/VizDoom/scenarios/deadly_corridor_s3.cfg')
model.set_env(env)
model.learn(total_timesteps=40000, callback=callback)

# %%
env = VizDoomGym(config='github/VizDoom/scenarios/deadly_corridor_s4.cfg')
model.set_env(env)
model.learn(total_timesteps=40000, callback=callback)

# %%
env = VizDoomGym(config='github/VizDoom/scenarios/deadly_corridor_s5.cfg')
model.set_env(env)
model.learn(total_timesteps=40000, callback=callback)

# %% [markdown]
# # 6. Test the Model

# %%
# Import eval policy to test agent
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Reload model from disc
model = PPO.load(r'D:\Nam 2\ThayHoangAI\FPSGame\DeadlyCorridor560k.zip')
# Out:
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object lr_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: an integer is required (got type bytes)
#   warnings.warn(
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\save_util.py:167: UserWarning: Could not deserialize object clip_range. Consider using `custom_objects` argument to replace this object.
# Exception: an integer is required (got type bytes)
#   warnings.warn(
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\base_class.py:751: UserWarning: You are probably loading a model saved with SB3 < 1.7.0, we deactivated exact_match so you can save the model again to avoid issues in the future (see https://github.com/DLR-RM/stable-baselines3/issues/1233 for more info). Original error: Error(s) in loading state_dict for ActorCriticCnnPolicy:
# 	Missing key(s) in state_dict: "pi_features_extractor.cnn.0.weight", "pi_features_extractor.cnn.0.bias", "pi_features_extractor.cnn.2.weight", "pi_features_extractor.cnn.2.bias", "pi_features_extractor.cnn.4.weight", "pi_features_extractor.cnn.4.bias", "pi_features_extractor.linear.0.weight", "pi_features_extractor.linear.0.bias", "vf_features_extractor.cnn.0.weight", "vf_features_extractor.cnn.0.bias", "vf_features_extractor.cnn.2.weight", "vf_features_extractor.cnn.2.bias", "vf_features_extractor.cnn.4.weight", "vf_features_extractor.cnn.4.bias", "vf_features_extractor.linear.0.weight", "vf_features_extractor.linear.0.bias".
# Note: the model should still work fine, this only a warning.
#   warnings.warn(

# %%
# Create rendered environment
env = VizDoomGym(render=True, config='github/VizDoom/scenarios/deadly_corridor_s1.cfg')

# %%
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=1)
mean_reward
# Out:
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# c:\Users\APTS\anaconda3\envs\RLenv\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# 1249.6622924804688

# %%
# Create rendered environment
env = VizDoomGym(render=True, config='github/VizDoom/scenarios/deadly_corridor_s2.cfg')
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=1)
env.close()
mean_reward
# Out:
# 1860.4078674316406

# %%
# Create rendered environment
env = VizDoomGym(render=True, config='github/VizDoom/scenarios/deadly_corridor_s3.cfg')
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=1)
env.close()
mean_reward
# Out:
# 2747.848342895508

# %%
# Create rendered environment
env = VizDoomGym(render=True, config='github/VizDoom/scenarios/deadly_corridor_s4.cfg')
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=1)
env.close()
mean_reward
# Out:
# 1393.9759216308594

# %%
# Create rendered environment
env = VizDoomGym(render=True, config='github/VizDoom/scenarios/deadly_corridor_s5.cfg')
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=1)
env.close()
mean_reward
# Out:
# 1220.9663543701172

# %%
for episode in range(20): 
    obs = env.reset()
    done = False
    total_reward = 0
    while not done: 
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        time.sleep(0.02)
        total_reward += reward
    print('Total Reward for episode {} is {}'.format(episode, total_reward))
    time.sleep(2)
# Out:
# Total Reward for episode 0 is 890.7953948974609
# Total Reward for episode 1 is 2357.024459838867
# Total Reward for episode 2 is 1128.299072265625
# Total Reward for episode 3 is 1454.3997192382812
# Total Reward for episode 4 is -44.435943603515625
# Total Reward for episode 5 is 1637.2250671386719
# Total Reward for episode 6 is 2037.8232879638672
# Total Reward for episode 7 is 1139.414535522461
# Total Reward for episode 8 is 775.8251800537109
# Total Reward for episode 9 is 2627.0672760009766
# Total Reward for episode 10 is 784.4347686767578
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 8
#       6     action, _ = model.predict(obs)
#       7     obs, reward, done, info = env.step(action)
# ----> 8     time.sleep(0.02)
#       9     total_reward += reward
#      10 print('Total Reward for episode {} is {}'.format(episode, total_reward))
#
# KeyboardInterrupt:
